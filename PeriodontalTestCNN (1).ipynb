# %%
import tensorflow as tf
import gdown
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# !mkdir dataset

# %%
import zipfile
import os

zip_path = '/content/dataset/periodontal_disease.zip'
extract_to = '/content/dataset'

def extract_zip(zip_path, extract_to):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
        print(f"Extraction completed to: {extract_to}")

if not os.path.exists(extract_to):
    os.makedirs(extract_to)

extract_zip(zip_path, extract_to)

os.remove(zip_path)


# Fungsi untuk mengunduh file dari Google Drive menggunakan URL
# def download_file_from_google_drive(url, dest_path):
#     gdown.download(url, dest_path, quiet=False)

# Fungsi untuk mengekstrak file zip
# def extract_zip_file(zip_path, extract_to):
#     with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#         zip_ref.extractall(extract_to)
#         print(f"File diekstraksi ke: {extract_to}")

# # URL file Google Drive
# url = 'https://drive.google.com/file/d/1BMX_Negz0OXg7yGv_YTOxkHrAFHjtFEL/view?usp=sharing'
# destination = 'dataset.zip'
# extract_to = 'dataset'  # Direktori tujuan untuk mengekstraksi file

# # Unduh file dari Google Drive
# download_file_from_google_drive(url, destination)

# # Ekstrak file zip
# if not os.path.exists(extract_to):
#     os.makedirs(extract_to)

# extract_zip_file(destination, extract_to)

# # Hapus file zip setelah diekstraksi (opsional)
# os.remove(destination)
# Out:
# Extraction completed to: /content/dataset

# %%
dataset_dir = '/content/dataset/periodontal_disease'

train_dir = os.path.join(dataset_dir, 'train')
validation_dir = os.path.join(dataset_dir, 'val')

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    horizontal_flip=True,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest'
)

validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(300, 300),
    batch_size=32,
    class_mode='binary'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(300, 300),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 132 images belonging to 2 classes.
# Found 44 images belonging to 2 classes.

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    # Check if 'val_accuracy' exists in the logs before comparing
    if logs.get('accuracy', 0) > 0.8 and logs.get('val_accuracy', 0) > 0.8:
      print("\nReached 80% accuracy so cancelling training!")
      self.model.stop_training = True

# %%
# @title Default title text
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation = 'relu', input_shape=(300, 300, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy',
              optimizer=RMSprop(learning_rate=0.001),
              metrics=['accuracy'])

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator
)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 23s 4s/step - loss: 24.8353 - accuracy: 0.6212 - val_loss: 0.8151 - val_accuracy: 0.3636
# Epoch 2/50
# 5/5 [==============================] - 19s 4s/step - loss: 1.8180 - accuracy: 0.5909 - val_loss: 0.7399 - val_accuracy: 0.6364
# Epoch 3/50
# 5/5 [==============================] - 21s 4s/step - loss: 1.0474 - accuracy: 0.5303 - val_loss: 0.6795 - val_accuracy: 0.6364
# Epoch 4/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.7859 - accuracy: 0.4394 - val_loss: 0.6763 - val_accuracy: 0.6364
# Epoch 5/50
# 5/5 [==============================] - 21s 5s/step - loss: 0.7565 - accuracy: 0.6212 - val_loss: 0.6675 - val_accuracy: 0.6364
# Epoch 6/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.7007 - accuracy: 0.6439 - val_loss: 0.6628 - val_accuracy: 0.6364
# Epoch 7/50
# 5/5 [==============================] - 21s 4s/step - loss: 0.6612 - accuracy: 0.6439 - val_loss: 0.6631 - val_accuracy: 0.6364
# Epoch 8/50
# 5/5 [==============================] - 20s 4s/step - loss: 0.6735 - accuracy: 0.6288 - val_loss: 0.6605 - val_accuracy: 0.6364
# Epoch 9/50
# 5/5 [==============================] - 21s 4s/step - loss: 0.6381 - accuracy: 0.6742 - val_loss: 0.6940 - val_accuracy: 0.6364
# Epoch 10/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.6792 - accuracy: 0.5985 - val_loss: 0.7527 - val_accuracy: 0.6364
# Epoch 11/50
# 5/5 [==============================] - 21s 4s/step - loss: 0.6703 - accuracy: 0.6136 - val_loss: 0.6583 - val_accuracy: 0.6136
# Epoch 12/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.6926 - accuracy: 0.6439 - val_loss: 0.6741 - val_accuracy: 0.6364
# Epoch 13/50
# 5/5 [==============================] - 21s 4s/step - loss: 0.6857 - accuracy: 0.5833 - val_loss: 0.6956 - val_accuracy: 0.2955
# Epoch 14/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.6940 - accuracy: 0.4924 - val_loss: 0.6903 - val_accuracy: 0.6136
# Epoch 15/50
# 5/5 [==============================] - 21s 5s/step - loss: 0.6916 - accuracy: 0.5909 - val_loss: 0.6956 - val_accuracy: 0.5000
# Epoch 16/50
# 5/5 [==============================] - 19s 4s/step - loss: 0.7407 - accuracy: 0.5455 - val_loss: 0.6586 - val_accuracy: 0.6364
# Epoch 17/50
# 5/5 [==============================] - 21s 4s/step - loss: 0.